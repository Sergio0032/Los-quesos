# %%
import pandas as pd 

df = pd.read_csv("../data/clasificacion_2024.csv")

df.head(90)
# Out:
# Running cells with '.venv (Python 3.13.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"d:/DAVID/UNIVERSIDAD/Grado en IA/Proyecto software/Los-quesos/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'

# %%
import pandas as pd
import ast

df = pd.read_csv("../data/clasificacion_2024.csv")

tabla = df["clasificacion_2024"].apply(ast.literal_eval)
