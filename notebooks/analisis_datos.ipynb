# %%
import pandas as pd 

df = pd.read_csv("../data/clasificacion_2024.csv")

df.head(90)
# Out:
#               Liga  Posicion             Equipo  Puntos  Partidos_Jugados  \
# 0   Premier_League         1          Liverpool      84                38
# 1   Premier_League         2            Arsenal      74                38
# 2   Premier_League         3    Manchester City      71                38
# 3   Premier_League         4            Chelsea      69                38
# 4   Premier_League         5          Newcastle      66                38
# ..             ...       ...                ...     ...               ...
# 85         Ligue_1         8               Lens      52                34
# 86         Ligue_1         9  Stade Brestois 29      50                34
# 87         Ligue_1        10           Toulouse      42                34
# 88         Ligue_1        11            Auxerre      42                34
# 89         Ligue_1        12             Rennes      41                34
#
#     Ganados  Empatados  Perdidos  Goles a favor  Goles en contra  \
# ...

# %%
df.iloc(50)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\sergo\OneDrive\Documents\GitHub\Los-quesos\.venv\Lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     523             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     524         except KeyError as err:
# --> 525             raise ValueError(
#     526                 f"No axis named {axis} for object type {cls.__name__}"
#
# KeyError: 50
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1100\482936592.py in ?()
# ----> 1 df.iloc(50)
#
# c:\Users\sergo\OneDrive\Documents\GitHub\Los-quesos\.venv\Lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     762         # we need to return a copy of ourselves
#     763         new_self = type(self)(self.name, self.obj)
#     764
# ...

# %%
import pandas as pd
import ast

df = pd.read_csv("../data/clasificacion_2024.csv")

tabla = df["clasificacion_2024"].apply(ast.literal_eval)
